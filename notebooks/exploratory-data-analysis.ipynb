# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Analysis

# %%
PATH = r'../data/train_eegs'
dir = os.listdir(r'../data/train_eegs')

# for file in dir[:5]:
#   file = os.path.join(PATH, file)
#   data = pd.read_parquet(file)
#   data.info()

sample_file = os.path.join(PATH, dir[3])
data = pd.read_parquet(sample_file)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40800 entries, 0 to 40799
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Fp1     40800 non-null  float32
#  1   F3      40800 non-null  float32
#  2   C3      40800 non-null  float32
#  3   P3      40800 non-null  float32
#  4   F7      40800 non-null  float32
#  5   T3      40800 non-null  float32
#  6   T5      40800 non-null  float32
#  7   O1      40800 non-null  float32
#  8   Fz      40800 non-null  float32
#  9   Cz      40800 non-null  float32
#  10  Pz      40800 non-null  float32
#  11  Fp2     40800 non-null  float32
#  12  F4      40800 non-null  float32
#  13  C4      40800 non-null  float32
#  14  P4      40800 non-null  float32
#  15  F8      40800 non-null  float32
#  16  T4      40800 non-null  float32
#  17  T6      40800 non-null  float32
#  18  O2      40800 non-null  float32
#  19  EKG     40800 non-null  float32
# dtypes: float32(20)
# ...

# %%
data.head()
# Out:
#       Fp1      F3      C3      P3      F7      T3      T5      O1      Fz  \
# 0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0
# 1  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0
# 2  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0
# 3  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0
# 4  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0
#
#        Cz      Pz     Fp2      F4      C4      P4      F8      T4      T6  \
# 0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0
# 1  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0
# 2  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0
# 3  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0
# 4  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0  9999.0
#
#        O2  EKG
# 0  9999.0  0.0
# 1  9999.0  0.0
# 2  9999.0  0.0
# ...

# %%
data.describe()
# Out:
#                 Fp1            F3            C3            P3            F7  \
# count  40800.000000  40800.000000  40800.000000  40800.000000  40800.000000
# mean    1002.105408    962.823242    950.107849    942.701660   1036.215576
# std     2964.707275   2987.745605   2997.579102   2990.966797   2961.488037
# min    -1694.619995  -4073.760010  -4920.370117  -3459.399902  -3652.649902
# 25%       -0.452500    -31.070000    -41.959999    -59.662499     48.509998
# 50%       45.184999     29.000000     24.675000      1.810000    107.024998
# 75%       96.650002     92.602499     96.462500     66.732502    167.000000
# max     9999.000000   9999.000000   9999.000000   9999.000000   9999.000000
#
#                  T3            T5            O1            Fz            Cz  \
# count  40800.000000  40800.000000  40800.000000  40800.000000  40800.000000
# mean     920.396973    938.829834    951.509521   1005.798523    957.025757
# ...

# %%
data["EKG"].value_counts()
# Out:
# EKG
#  0.000000      4014
#  123.739998       8
#  115.360001       7
# -106.940002       7
#  136.250000       7
#                ...
#  103.410004       1
#  53.630001        1
# -69.320000        1
#  164.240005       1
# -16.110001        1
# Name: count, Length: 23276, dtype: int64

# %%
data.hist(bins=50, figsize=(15, 20))
# Out:
# array([[<Axes: title={'center': 'Fp1'}>, <Axes: title={'center': 'F3'}>,
#         <Axes: title={'center': 'C3'}>, <Axes: title={'center': 'P3'}>],
#        [<Axes: title={'center': 'F7'}>, <Axes: title={'center': 'T3'}>,
#         <Axes: title={'center': 'T5'}>, <Axes: title={'center': 'O1'}>],
#        [<Axes: title={'center': 'Fz'}>, <Axes: title={'center': 'Cz'}>,
#         <Axes: title={'center': 'Pz'}>, <Axes: title={'center': 'Fp2'}>],
#        [<Axes: title={'center': 'F4'}>, <Axes: title={'center': 'C4'}>,
#         <Axes: title={'center': 'P4'}>, <Axes: title={'center': 'F8'}>],
#        [<Axes: title={'center': 'T4'}>, <Axes: title={'center': 'T6'}>,
#         <Axes: title={'center': 'O2'}>, <Axes: title={'center': 'EKG'}>]],
#       dtype=object)

# %% [markdown]
# ### Notes:
# Data is very widely distributed, probably need to implement a scaler as part of data preprocessing pipeline
# No need for feature engineering, as these coorelate to different parts of the brain and thus are all important
# Multiclass tabular machine learning algorithms would do well on this data
